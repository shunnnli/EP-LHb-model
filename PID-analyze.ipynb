# %% [markdown]
# ## Load batch data

# %%
import os, sys
import pickle
from summary_plots import load_batches, plot_pid_results

script_dir = os.getcwd()
results_root = os.path.join(script_dir, "PID-results-ext_buffer")

all_rewards, all_td, success_trials, cue_errors, t_axis, ant_licks, stuck_counts, all_batch_extras = load_batches(results_root)
# Out:
# Loading results from: /Users/elliotjerng/Downloads/#Northeastern/coop/EP-LHb-model/PID-results-ext_buffer/20250916-kd_omission_sweep
# Extracting data from batches...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/fl/851gv91d4qs7wzb_myf71kxc0000gn/T/ipykernel_11779/1737962626.py in <module>
#       6 results_root = os.path.join(script_dir, "PID-results-ext_buffer")
#       7
# ----> 8 all_rewards, all_td, success_trials, cue_errors, t_axis, ant_licks, stuck_counts, all_batch_extras = load_batches(results_root)
#
# ~/Downloads/#Northeastern/coop/EP-LHb-model/summary_plots.py in load_batches(root_dir, filter_kd, filter_omit, filter_max_b, filter_num_r, filter_repeat)
#     209     # extract data
#     210     print("Extracting data from batches...")
# --> 211     all_rewards, all_td, success_trials, cue_errors, t_axis, ant_licks, stuck_counts, all_batch_extras = extract_batch_data(batches)
#     212
#     213     return all_rewards, all_td, success_trials, cue_errors, t_axis, ant_licks, stuck_counts, all_batch_extras
#
# ~/Downloads/#Northeastern/coop/EP-LHb-model/summary_plots.py in extract_batch_data(batches)
#     125             all_batch_extras[k][batch_name] = per_session
#     126
# --> 127     return all_batch_rewards, all_batch_td, success_trials, all_batch_cue_errors, t_axis, all_batch_ant_licks, all_batch_stuck_counts, all_batch_extras
#     128
#     129
#
# UnboundLocalError: local variable 't_axis' referenced before assignment

# %% [markdown]
# ## Plot XXXX
