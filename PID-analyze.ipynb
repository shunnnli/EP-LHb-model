# %% [markdown]
# ## Load batch data

# %%
import os, sys
import pickle
from summary_plots import load_batches, plot_pid_results

script_dir = os.getcwd()
results_root = os.path.join(script_dir, "PID-results-ext_buffer")

all_rewards, all_td, success_trials, cue_errors, t_axis, ant_licks, stuck_counts, all_batch_extras = load_batches(results_root)
# Out:
# Loading results from: /Users/elliotjerng/Downloads/#Northeastern/coop/EP-LHb-model/PID-results-ext_buffer/20250903-kd_omission_sweep
# 2025-09-06 11:02:12.650061: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Extracting data from batches...
# Processing batch: (0, 0, 1, 1)
# Processing batch: (0.1, 0, 1, 1)
# Processing batch: (0, 0.1, 1, 1)
# Processing batch: (0.1, 0.1, 1, 1)
# Processing batch: (0, 0, 5, 5)
# Processing batch: (0.1, 0, 5, 5)
# Processing batch: (0, 0.1, 5, 5)
# Processing batch: (0.1, 0.1, 5, 5)

# %% [markdown]
# ## Plot Entire Summary Plot

# %%
plot_pid_results(results_root)
# Out:
# Loading results from: /Users/elliotjerng/Downloads/#Northeastern/coop/EP-LHb-model/PID-results-ext_buffer/20250903-kd_omission_sweep
# Extracting data from batches...
# Processing batch: (0, 0, 1, 1)
# Processing batch: (0.1, 0, 1, 1)
# Processing batch: (0, 0.1, 1, 1)
# Processing batch: (0.1, 0.1, 1, 1)
# Processing batch: (0, 0, 5, 5)
# Processing batch: (0.1, 0, 5, 5)
# Processing batch: (0, 0.1, 5, 5)
# Processing batch: (0.1, 0.1, 5, 5)
# Plotting reward distributions...
# Plotting TD amplitudes (last 25%)...
# Plotting success trials...
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...

# %% [markdown]
# ## Plot Only Specific Settings (ex. only kd = 0, omit = 0, or only max_b = 1, num_r = 1)

# %%
plot_pid_results(results_root, filter_kd=[0], filter_omit=[0])  # Only kd=0, omit=0
# Out:
# Loading results from: /Users/elliotjerng/Downloads/#Northeastern/coop/EP-LHb-model/PID-results-ext_buffer/20250903-kd_omission_sweep
# Applied filters: kd=[0], omit=[0], max_b=None, num_r=None, repeat=None
# Filtered from 8 to 2 batches
# Extracting data from batches...
# Processing batch: (0, 0, 1, 1)
# Processing batch: (0, 0, 5, 5)
# Plotting reward distributions...
# Plotting TD amplitudes (last 25%)...
# Plotting success trials...
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:45: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ...

# %%
plot_pid_results(results_root, filter_max_b=[1], filter_num_r=[1])  # Only max_b=1, num_r=1
# Out:
# Loading results from: /Users/elliotjerng/Downloads/#Northeastern/coop/EP-LHb-model/PID-results-ext_buffer/20250903-kd_omission_sweep
# Applied filters: kd=None, omit=None, max_b=[1], num_r=[1], repeat=None
# Filtered from 8 to 4 batches
# Extracting data from batches...
# Processing batch: (0, 0, 1, 1)
# Processing batch: (0.1, 0, 1, 1)
# Processing batch: (0, 0.1, 1, 1)
# Processing batch: (0.1, 0.1, 1, 1)
# Plotting reward distributions...
# Plotting TD amplitudes (last 25%)...
# Plotting success trials...
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:45: RuntimeWarning: invalid value encountered in reduce
# ...
